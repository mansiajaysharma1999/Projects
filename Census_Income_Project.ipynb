# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("census_income.csv")
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
print("print rows and column :", df.shape)
# Out:
# print rows and column : (32560, 15)

# %% [markdown]
# There are 32,560 rows and 15 columns

# %% [markdown]
# # Data Info:-

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# There are 15 columns
#
# 1. six are integer
# 2. Nine are objective
#
# The Target Variable are Catagorical (Income)
#
# Income has two catagories:
#
# 1. lessthan and equal to 50k
# 2. greaterthan 50k

# %% [markdown]
# # Check Null Values

# %%
df.isnull().sum().any()
# Out:
# False

# %%
df.isin(['?']).sum().any()
# Out:
# False

# %% [markdown]
# no null are present

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
Income=df['Income'].value_counts()
Income
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
percentage=Income/32560*100
percentage
# Out:
#  <=50K    75.918305
#  >50K     24.081695
# Name: Income, dtype: float64

# %% [markdown]
# 75% person's income are less than  or equal to 50k
#
# 24% person's income are greater than 50k

# %%
# workclass
plt.figure(figsize=(20,5))

sns.countplot(df['Workclass'],hue=df['Income'])
plt.title(' Distribution of Income ',fontsize=20)
# Out:
# Text(0.5, 1.0, ' Distribution of Income ')

# %% [markdown]
# 0 means less than or equal to 50k
#
# 1 means greater than 50k

# %%
# visualise the Target variable
sns.countplot(df['Income'])
plt.title("Distribution of income",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of income')

# %% [markdown]
# persons whose income is less than or equal to 50k is more as compare to the person whose income is greater than 50k

# %%
# Maririal Status
plt.figure(figsize=(20,5))

sns.countplot(df['Marital_status'],hue=df['Income'])
plt.title('Marital_status',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Marital_status')

# %% [markdown]
# from the above info
#
# Never married means most of the single person earn less than or equal to 50k
#
# most of the person who are married they earn almost equally less than 50k 0r greater than 50k

# %%
occupation_values=df['Occupation'].value_counts()
occupation_values


occupation_percent=occupation_values/df.shape[0]*100
occupation_percent
# Out:
#  Prof-specialty       12.714988
#  Craft-repair         12.589066
#  Exec-managerial      12.487715
#  Adm-clerical         11.575553
#  Sales                11.210074
#  Other-service        10.119779
#  Machine-op-inspct     6.148649
#  ?                     5.660319
#  Transport-moving      4.904791
#  Handlers-cleaners     4.207617
#  Farming-fishing       3.052826
#  Tech-support          2.850123
#  Protective-serv       1.993243
#  Priv-house-serv       0.457617
#  Armed-Forces          0.027641
# Name: Occupation, dtype: float64

# %%
occupation=df['Occupation'].unique()
occupation
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
# make DataFrame
occupation=pd.DataFrame({'Occupation':occupation,'occupation_values':occupation_values,'occupation in percent(%)':occupation_percent})
occupation
# Out:
#                             Occupation  occupation_values  \
#  Prof-specialty        Exec-managerial               4140
#  Craft-repair        Handlers-cleaners               4099
#  Exec-managerial        Prof-specialty               4066
#  Adm-clerical            Other-service               3769
#  Sales                    Adm-clerical               3650
#  Other-service                   Sales               3295
#  Machine-op-inspct        Craft-repair               2002
#  ?                    Transport-moving               1843
#  Transport-moving      Farming-fishing               1597
#  Handlers-cleaners   Machine-op-inspct               1370
#  Farming-fishing          Tech-support                994
#  Tech-support                        ?                928
#  Protective-serv       Protective-serv                649
#  Priv-house-serv          Armed-Forces                149
#  Armed-Forces          Priv-house-serv                  9
#
# ...

# %%
# Occupation
plt.figure(figsize=(20,5))

sns.countplot(df['Occupation'],hue=df['Income'])
plt.title('Occupation',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Occupation')

# %%
#Relationship
plt.figure(figsize=(20,5))

sns.countplot(df['Relationship'],hue=df['Income'])
plt.title('Relationship',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Relationship')

# %%
# Race
plt.figure(figsize=(20,5))

sns.countplot(df['Race'],hue=df['Income'])
plt.title('Race',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Race')

# %%
# Sex
plt.figure(figsize=(20,5))

sns.countplot(df['Sex'],hue=df['Income'])
plt.title('Sex',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sex')

# %% [markdown]
# as compare to female , male person earn more than female person

# %%
# Native_country
plt.figure(figsize=(25,5))

sns.countplot(df['Native_country'],hue=df['Income'])
plt.title('Native_country',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Native_country')

# %%
print("No.of Unique Value :", df['Native_country'].nunique())
# Out:
# No.of Unique Value : 42

# %% [markdown]
# There are 42 Native country

# %%
pd.crosstab(df['Income'],df['Native_country'])
# Out:
# Native_country    ?   Cambodia   Canada   China   Columbia   Cuba  \
# Income
#  <=50K          437         12       82      55         57     70
#  >50K           146          7       39      20          2     25
#
# Native_country   Dominican-Republic   Ecuador   El-Salvador   England  ...  \
# Income                                                                 ...
#  <=50K                           68        24            97        60  ...
#  >50K                             2         4             9        30  ...
#
# Native_country   Portugal   Puerto-Rico   Scotland   South   Taiwan  \
# Income
#  <=50K                 33           102          9      64       31
#  >50K                   4            12          3      16       20
#
# Native_country   Thailand   Trinadad&Tobago   United-States   Vietnam  \
# Income
#  <=50K                 15                17           21998        62
#  >50K                   3                 2            7171         5
#
# ...

# %%
# workclass
plt.figure(figsize=(25,5))

sns.countplot(df['Workclass'],hue=df['Income'])
plt.title('Workclass',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Workclass')

# %% [markdown]
# we can say that govt Employes are less, most of private Employes earn less than 50k
#
# whereas Private Employes are more, half of govt Employes earn less than 50k and greater than 50k

# %% [markdown]
# # Encoding the variables

# %%
Categorical_feature = [feature for feature in df.columns if df[feature].dtypes == 'O']
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in Categorical_feature:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %% [markdown]
# # Check Correlation

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Maritial Status and Relationship are highly Positive Correlated, we will drop one of them
#
# Education and Education_num are positively correlate to each other

# %%
# drop the column
df.drop(['Relationship'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#                 Age     Workclass        Fnlwgt     Education  Education_num  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000   32560.000000
# mean      38.581634      3.868796  1.897818e+05     10.298249      10.080590
# std       13.640642      1.455879  1.055498e+05      3.870317       2.572709
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      4.000000  1.178315e+05      9.000000       9.000000
# 50%       37.000000      4.000000  1.783630e+05     11.000000      10.000000
# 75%       48.000000      4.000000  2.370545e+05     12.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        Marital_status    Occupation          Race           Sex  Capital_gain  \
# count    32560.000000  32560.000000  32560.000000  32560.000000  32560.000000
# mean         2.611794      6.572912      3.665848      0.669195   1077.615172
# ...

# %% [markdown]
# # Numerical Analysis

# %% [markdown]
# # Check Disrtibution With Income

# %%
catagorical_feature = [feature for feature in df.columns if df[feature].dtypes == 'O']
Numerical_feature = [feature for feature in df.columns if df[feature].dtypes != 'O']

# %%
Numerical_feature = [feature for feature in df.columns if df[feature].dtypes != 'O']
for num in Numerical_feature:
    plt.figure(figsize=(20,8))
    sns.distplot(df[df['Income']==0][num])
    sns.distplot(df[df['Income']==1][num])
    plt.legend(labels=['<=50k','>50k'])
    plt.xlabel(num,fontsize='18')

# %%
plt.figure(figsize=(35,25))
plotnumber=1

for i in df.columns:
    if plotnumber <= 24:
        ax=plt.subplot(5,5,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=15)
        
    plotnumber +=1

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.837097   1.463883  1.008742   0.335443       1.134779
# 1      0.042640   0.090121  0.245046   0.181319       0.420027
# 2      1.057031   0.090121  0.425770   2.402489       1.197429
# 3      0.775755   0.090121  1.408146   0.335443       1.134779
# 4      0.115952   0.090121  0.898170   0.439700       1.523480
# ...         ...        ...       ...        ...            ...
# 32555  0.849066   0.090121  0.639710   0.852204       0.746077
# 32556  0.103982   0.090121  0.335466   0.181319       0.420027
# 32557  1.423589   0.090121  0.358811   0.181319       0.420027
# 32558  1.215624   0.090121  0.110927   0.181319       0.420027
# 32559  0.983720   0.777002  0.929862   0.181319       0.420027
#
#        Marital_status  Occupation      Race       Sex  Capital_gain  \
# 0            0.406183    0.608434  0.393675  0.703087      0.145914
# 1            1.734026    0.135480  0.393675  0.703087      0.145914
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([12, 11,  7, ...,  7,  7,  7], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 4       37          4  284582         12             14               2
# 5       49          4  160187          6              5               3
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Race  Sex  Capital_gain  Capital_loss  Hours_per_week  \
# ...

# %%
print("shape of old Data :", df.shape)
print("shape of new data :",df1.shape)
# Out:
# shape of old Data : (32560, 14)
# shape of new data : (27417, 14)

# %% [markdown]
# # feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()

# %%
# split into x and y
x=df1.drop(['Income'],axis=1)
y=df1['Income']

# %%
x
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 4       37          4  284582         12             14               2
# 5       49          4  160187          6              5               3
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Race  Sex  Capital_gain  Capital_loss  Hours_per_week  \
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 4        0
# 5        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 27417, dtype: int32

# %%
x=st.fit_transform(x)
x
# Out:
# array([[ 0.88273868,  1.47439128, -1.08632701, ..., -0.03745297,
#         -2.4121897 ,  0.1938942 ],
#        [-0.01173679,  0.09284389,  0.31020881, ..., -0.03745297,
#          0.00820029,  0.1938942 ],
#        [ 1.10635755,  0.09284389,  0.51150794, ..., -0.03745297,
#          0.00820029,  0.1938942 ],
#        ...,
#        [ 1.47905566,  0.09284389, -0.3623994 , ..., -0.03745297,
#          0.00820029,  0.1938942 ],
#        [-1.20437075,  0.09284389,  0.16082005, ..., -0.03745297,
#         -1.78468118,  0.1938942 ],
#        [ 1.03181793,  0.78361759,  1.07299269, ..., -0.03745297,
#          0.00820029,  0.1938942 ]])

# %%
# visualise Target Variable
sns.countplot(df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
df1['Income'].value_counts()
# Out:
# 0    21279
# 1     6138
# Name: Income, dtype: int64

# %% [markdown]
# There is huge difference betweem both the income
#
# so it is  a inbalaned data

# %% [markdown]
# # Apply Smote

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()

# %%
x,y=smt.fit_resample(x,y)

# %%
print(x.shape),print(y.shape)
# Out:
# (42558, 13)
# (42558,)
# (None, None)

# %% [markdown]
# # splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
print(x_train.shape),print(x_test.shape),print(y_train.shape),print(y_test.shape)
# Out:
# (29790, 13)
# (12768, 13)
# (29790,)
# (12768,)
# (None, None, None, None)

# %% [markdown]
# # import Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %% [markdown]
# # Logistic Regression

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
predlg_train=lg.predict(x_train)
print("Accuracy_score :", accuracy_score(y_test,predlg))
print("Accuracy_score : ", accuracy_score(y_train,predlg_train))
print("confusion matrix :", confusion_matrix(y_test,predlg))
print("classification_report :", classification_report(y_test,predlg))
# Out:
# Accuracy_score : 0.7700501253132832
# Accuracy_score :  0.7658610271903323
# confusion matrix : [[4891 1504]
#  [1432 4941]]
# classification_report :               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77      6395
#            1       0.77      0.78      0.77      6373
#
#     accuracy                           0.77     12768
#    macro avg       0.77      0.77      0.77     12768
# weighted avg       0.77      0.77      0.77     12768

# %%
y_pred_prob=lg.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title("Logistic Regression")

auc_scorelg=roc_auc_score(y_test,lg.predict(x_test))
auc_scorelg
# Out:
# 0.7700591591260383

# %% [markdown]
# # KNN

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
predknn_train=knn.predict(x_train)
print("Accuracy_score :", accuracy_score(y_test,predknn))
print("Accuracy_score : ", accuracy_score(y_train,predknn_train))
print("confusion matrix :", confusion_matrix(y_test,predknn))
print("classification_report :", classification_report(y_test,predknn))
# Out:
# Accuracy_score : 0.8601190476190477
# Accuracy_score :  0.9004028197381672
# confusion matrix : [[5005 1390]
#  [ 396 5977]]
# classification_report :               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85      6395
#            1       0.81      0.94      0.87      6373
#
#     accuracy                           0.86     12768
#    macro avg       0.87      0.86      0.86     12768
# weighted avg       0.87      0.86      0.86     12768

# %%
y_pred_prob=knn.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title("KNeighbors Classifire")

auc_scoreknn=roc_auc_score(y_test,knn.predict(x_test))
auc_scoreknn
# Out:
# 0.8602527742686938

# %% [markdown]
# # DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
preddtc_train=dtc.predict(x_train)
print("Accuracy_score :", accuracy_score(y_test,preddtc))
print("Accuracy_score : ", accuracy_score(y_train,preddtc_train))
print("confusion matrix :", confusion_matrix(y_test,preddtc))
print("classification_report :", classification_report(y_test,preddtc))
# Out:
# Accuracy_score : 0.8508771929824561
# Accuracy_score :  0.9999664316884861
# confusion matrix : [[5371 1024]
#  [ 880 5493]]
# classification_report :               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      6395
#            1       0.84      0.86      0.85      6373
#
#     accuracy                           0.85     12768
#    macro avg       0.85      0.85      0.85     12768
# weighted avg       0.85      0.85      0.85     12768

# %%
y_pred_prob=dtc.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title("DecisionTreeClassifier")

auc_scoredtc=roc_auc_score(y_test,dtc.predict(x_test))
auc_scoredtc
# Out:
# 0.8508961832849613

# %% [markdown]
# # GaussianNB

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
predgnb=gnb.predict(x_test)
predgnb_train=gnb.predict(x_train)
print("Accuracy_score :", accuracy_score(y_test,predgnb))
print("Accuracy_score : ", accuracy_score(y_train,predgnb_train))
print("confusion matrix :", confusion_matrix(y_test,predgnb))
print("classification_report :", classification_report(y_test,predgnb))
# Out:
# Accuracy_score : 0.7817982456140351
# Accuracy_score :  0.7854313528029541
# confusion matrix : [[4729 1666]
#  [1120 5253]]
# classification_report :               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77      6395
#            1       0.76      0.82      0.79      6373
#
#     accuracy                           0.78     12768
#    macro avg       0.78      0.78      0.78     12768
# weighted avg       0.78      0.78      0.78     12768

# %%
y_pred_prob=gnb.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title("GaussianNB")

auc_scoregnb=roc_auc_score(y_test,gnb.predict(x_test))
auc_scoregnb
# Out:
# 0.7818712813917491

# %% [markdown]
# # RanforestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
predrf_train=rf.predict(x_train)
print("Accuracy_score :", accuracy_score(y_test,predrf))
print("Accuracy_score : ", accuracy_score(y_train,predrf_train))
print("confusion matrix :", confusion_matrix(y_test,predrf))
print("classification_report :", classification_report(y_test,predrf))
# Out:
# Accuracy_score : 0.8979479949874687
# Accuracy_score :  0.9999664316884861
# confusion matrix : [[5635  760]
#  [ 543 5830]]
# classification_report :               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90      6395
#            1       0.88      0.91      0.90      6373
#
#     accuracy                           0.90     12768
#    macro avg       0.90      0.90      0.90     12768
# weighted avg       0.90      0.90      0.90     12768

# %%
y_pred_prob=rf.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title("RandomForestClassifier")

auc_scorerf=roc_auc_score(y_test,rf.predict(x_test))
auc_scorerf
# Out:
# 0.8979769765111733

# %% [markdown]
# # AdaBoostClassifier

# %%
ada=AdaBoostClassifier()
ada.fit(x_train,y_train)
predada=ada.predict(x_test)
predada_train=ada.predict(x_train)
print("Accuracy_score :", accuracy_score(y_test,predada))
print("Accuracy_score : ", accuracy_score(y_train,predada_train))
print("confusion matrix :", confusion_matrix(y_test,predada))
print("classification_report :", classification_report(y_test,predada))
# Out:
# Accuracy_score : 0.8493890977443609
# Accuracy_score :  0.8499832158442431
# confusion matrix : [[5272 1123]
#  [ 800 5573]]
# classification_report :               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.85      6395
#            1       0.83      0.87      0.85      6373
#
#     accuracy                           0.85     12768
#    macro avg       0.85      0.85      0.85     12768
# weighted avg       0.85      0.85      0.85     12768

# %%
y_pred_prob=ada.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title("AdaBoostClassifier")

auc_scoreada=roc_auc_score(y_test,ada.predict(x_test))
auc_scoreada
# Out:
# 0.8494322399754536

# %% [markdown]
# # GradientBoostingClassifier

# %%
gbr=GradientBoostingClassifier()
gbr.fit(x_train,y_train)
predgbr=gbr.predict(x_test)
predgbr_train=gbr.predict(x_train)
print("Accuracy_score :", accuracy_score(y_test,predgbr))
print("Accuracy_score : ", accuracy_score(y_train,predgbr_train))
print("confusion matrix :", confusion_matrix(y_test,predgbr))
print("classification_report :", classification_report(y_test,predgbr))
# Out:
# Accuracy_score : 0.8614505012531328
# Accuracy_score :  0.8682779456193354
# confusion matrix : [[5265 1130]
#  [ 639 5734]]
# classification_report :               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.86      6395
#            1       0.84      0.90      0.87      6373
#
#     accuracy                           0.86     12768
#    macro avg       0.86      0.86      0.86     12768
# weighted avg       0.86      0.86      0.86     12768

# %%
y_pred_prob=gbr.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title("GradientBoostingClassifier")

auc_scoregbr=roc_auc_score(y_test,gbr.predict(x_test))
auc_scoregbr
# Out:
# 0.861516351172184

# %%
svc=SVC()
svc.fit(x_train,y_train)
pred_svc=svc.predict(x_test)
predsvc_train=svc.predict(x_train)
print("Accuracy score of:",accuracy_score(y_test,pred_svc))
print("Accuracy score of training data:", accuracy_score(y_train,predsvc_train))
print("Confusion matrix:",confusion_matrix(y_test,pred_svc))
print("classification report:", classification_report(y_test,pred_svc))
# Out:
# Accuracy score of: 0.8354479949874687
# Accuracy score of training data: 0.8399462907015777
# Confusion matrix: [[4972 1423]
#  [ 678 5695]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83      6395
#            1       0.80      0.89      0.84      6373
#
#     accuracy                           0.84     12768
#    macro avg       0.84      0.84      0.83     12768
# weighted avg       0.84      0.84      0.83     12768

# %% [markdown]
# # Compare Model

# %%
models={"Models":['Logistic Regression','Decision Tree','GaussianNB','KNeighbors','RandomForest','AdaBoostClassifier',
                 'GradientBoostingClassifier'],"Score":[accuracy_score(y_test,predlg),accuracy_score(y_test,preddtc),
                  accuracy_score(y_test,predgnb),accuracy_score(y_test,predknn),accuracy_score(y_test,predrf),
                                                       accuracy_score(y_test,predada),accuracy_score(y_test,predgbr)],'auc_roc_score':[auc_scorelg,
                                                        auc_scoredtc,auc_scoregnb,auc_scoreknn,auc_scorerf,auc_scoreada,auc_scoregbr]}

# %%
df2=pd.DataFrame(models)

# %%
df2
# Out:
#                        Models     Score  auc_roc_score
# 0         Logistic Regression  0.770050       0.770059
# 1               Decision Tree  0.850877       0.850896
# 2                  GaussianNB  0.781798       0.781871
# 3                  KNeighbors  0.860119       0.860253
# 4                RandomForest  0.897948       0.897977
# 5          AdaBoostClassifier  0.849389       0.849432
# 6  GradientBoostingClassifier  0.861451       0.861516

# %%
plt.figure(figsize=(20,8))
sns.barplot(df2['Score'],df2['Models'])
plt.title('Model Comparison')
# Out:
# Text(0.5, 1.0, 'Model Comparison')

# %%
#Comparison with auc_roc_score
plt.figure(figsize=(20,8))
sns.barplot(df2['auc_roc_score'],df2['Models'])
plt.title('Model Comparison')
# Out:
# Text(0.5, 1.0, 'Model Comparison')

# %% [markdown]
# # Among all the models Random Forest model perform better than other

# %%
# cross Validation
from sklearn.model_selection import cross_val_score
score=cross_val_score(rf,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.8300047  0.88921523 0.9256344  0.92915051 0.92879803]
# 0.9005605720990879
# 0.03834131784841766

# %% [markdown]
# # save the best model

# %%
import pickle
filename='RandomForestClassifier'
pickle.dump(rf,open(filename,'wb'))

load_model=pickle.load(open(filename,'rb'))
load_model.predict(x_test)
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
conculusion=pd.DataFrame([load_model.predict(x_test)[:],(y_test)[:]],index=["Predicted","Original"])
conculusion
# Out:
#            0      1      2      3      4      5      6      7      8      \
# Predicted      1      1      0      1      1      1      0      0      1
# Original       1      1      0      1      1      1      0      0      1
#
#            9      ...  12758  12759  12760  12761  12762  12763  12764  12765  \
# Predicted      0  ...      1      0      1      1      1      0      1      1
# Original       0  ...      0      0      1      1      1      0      0      1
#
#            12766  12767
# Predicted      1      0
# Original       1      0
#
# [2 rows x 12768 columns]

# %% [markdown]
# #                        Thank You !
